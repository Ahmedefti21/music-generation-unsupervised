# %% [markdown]
# # Preprocessing: Building the Piano-Roll Dataset
# This notebook converts MIDI files from the MAESTRO dataset into binarized piano-roll matrices for training Tasks 1 and 2.

# %%
import sys
sys.path.append("../src")

import pandas as pd
import numpy as np
from pathlib import Path
from preprocessing.build_dataset import build_dataset

csv_path = '../data/raw_midi/maestro-v3.0.0/maestro-v3.0.0.csv'
midi_root = '../data/raw_midi/maestro-v3.0.0/'
out_dir = '../data/train_test_split/'

# %%
# Build dataset with a subset of files
build_dataset(csv_path, midi_root, out_dir, max_train=200, max_test=50)
